# %%
#import liabraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#to ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
#read the data
data = pd.read_csv("test.csv")

# %%
#display the last 5 observations of the dataset
print(data.tail())
# Out:
#             ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 11394  0x6909      JAPRES01DEL01                   35                     4.6
# 11395  0x443b      JAPRES11DEL01                   33                     4.9
# 11396  0x1ea5      SURRES11DEL03                 NaN                     NaN
# 11397  0x22d4      VADRES03DEL02                   27                     4.7
# 11398  0xb7be     CHENRES07DEL02                   39                       5
#
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 11394            26.905190             75.810753                   27.015190
# 11395            26.902940             75.793007                   26.912940
# 11396            21.157735             72.768778                   21.217735
# 11397            22.320000             73.170000                   22.450000
# 11398            13.081878             80.248519                   13.131878
#
# ...

# %%
#display the first 5 observations of the dataset
print(data.head())
# Out:
#         ID Delivery_person_ID Delivery_person_Age Delivery_person_Ratings  \
# 0  0x2318    COIMBRES13DEL01                 NaN                     NaN
# 1  0x3474     BANGRES15DEL01                   28                     4.6
# 2  0x9420      JAPRES09DEL03                   23                     4.5
# 3  0x72ee      JAPRES07DEL03                   21                     4.8
# 4  0xa759     CHENRES19DEL01                   31                     4.6
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            11.003669             76.976494                   11.043669
# 1            12.975377             77.696664                   13.085377
# 2            26.911378             75.789034                   27.001378
# 3            26.766536             75.837333                   26.856536
# 4            12.986047             80.218114                   13.096047
#
#    Delivery_location_longitude  Order_Date Time_Orderd Time_Order_picked  \
# ...

# %%
# describe the dataset
print(data.describe())
# Out:
#        Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# count         11399.000000          11399.000000                11399.000000
# mean             17.099934             70.399259                   17.569497
# std               8.193510             22.773144                    7.287440
# min             -30.902872            -88.400467                    0.010000
# 25%              12.933284             73.170937                   12.992532
# 50%              18.551440             75.897429                   18.643481
# 75%              22.732225             78.045732                   22.791226
# max              30.914057             88.433452                   31.054057
#
#        Delivery_location_longitude  Vehicle_condition
# count                 11399.000000       11399.000000
# mean                     71.102187           1.031406
# std                      20.693782           0.839599
# min                       0.010000           0.000000
# ...

# %%
#Display data type and information about data
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11399 entries, 0 to 11398
# Data columns (total 19 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   ID                           11399 non-null  object
#  1   Delivery_person_ID           11399 non-null  object
#  2   Delivery_person_Age          11399 non-null  object
#  3   Delivery_person_Ratings      11399 non-null  object
#  4   Restaurant_latitude          11399 non-null  float64
#  5   Restaurant_longitude         11399 non-null  float64
#  6   Delivery_location_latitude   11399 non-null  float64
#  7   Delivery_location_longitude  11399 non-null  float64
#  8   Order_Date                   11399 non-null  object
#  9   Time_Orderd                  11399 non-null  object
#  10  Time_Order_picked            11399 non-null  object
#  11  Weatherconditions            11399 non-null  object
# ...

# %%
#display the number of rows and columns in data
print(data.shape)
# Out:
# (11399, 19)

# %%
#descibe the columns
print(data.columns)
# Out:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Restaurant_latitude',
#        'Restaurant_longitude', 'Delivery_location_latitude',
#        'Delivery_location_longitude', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density',
#        'Vehicle_condition', 'Type_of_order', 'Type_of_vehicle',
#        'multiple_deliveries', 'Festival', 'City'],
#       dtype='object')

# %%
#Check for Duplication
print(data.nunique())
# Out:
# ID                             11399
# Delivery_person_ID              1297
# Delivery_person_Age               23
# Delivery_person_Ratings           29
# Restaurant_latitude              492
# Restaurant_longitude             434
# Delivery_location_latitude      3572
# Delivery_location_longitude     3572
# Order_Date                        44
# Time_Orderd                      177
# Time_Order_picked                193
# Weatherconditions                  7
# Road_traffic_density               5
# Vehicle_condition                  4
# Type_of_order                      4
# Type_of_vehicle                    4
# multiple_deliveries                5
# Festival                           3
# City                               4
# dtype: int64

# %%
#get the number of missing records in each column
print(data.isnull().sum())
# Out:
# ID                             0
# Delivery_person_ID             0
# Delivery_person_Age            0
# Delivery_person_Ratings        0
# Restaurant_latitude            0
# Restaurant_longitude           0
# Delivery_location_latitude     0
# Delivery_location_longitude    0
# Order_Date                     0
# Time_Orderd                    0
# Time_Order_picked              0
# Weatherconditions              0
# Road_traffic_density           0
# Vehicle_condition              0
# Type_of_order                  0
# Type_of_vehicle                0
# multiple_deliveries            0
# Festival                       0
# City                           0
# dtype: int64

# %%
#identify null values in the data
print(data.isnull())
# Out:
#           ID  Delivery_person_ID  Delivery_person_Age  \
# 0      False               False                False
# 1      False               False                False
# 2      False               False                False
# 3      False               False                False
# 4      False               False                False
# ...      ...                 ...                  ...
# 11394  False               False                False
# 11395  False               False                False
# 11396  False               False                False
# 11397  False               False                False
# 11398  False               False                False
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                        False                False                 False
# 1                        False                False                 False
# 2                        False                False                 False
# ...

# %%
# calculate the percentage of missing values in each column
print((data.isnull().sum()/(len(data)))*100)
# Out:
# ID                             0.0
# Delivery_person_ID             0.0
# Delivery_person_Age            0.0
# Delivery_person_Ratings        0.0
# Restaurant_latitude            0.0
# Restaurant_longitude           0.0
# Delivery_location_latitude     0.0
# Delivery_location_longitude    0.0
# Order_Date                     0.0
# Time_Orderd                    0.0
# Time_Order_picked              0.0
# Weatherconditions              0.0
# Road_traffic_density           0.0
# Vehicle_condition              0.0
# Type_of_order                  0.0
# Type_of_vehicle                0.0
# multiple_deliveries            0.0
# Festival                       0.0
# City                           0.0
# dtype: float64

# %%
# Provide a statistics summary of data belonging to numerical datatype such as int, float
print(data.describe().T)
# Out:
#                                count       mean        std        min  \
# Restaurant_latitude          11399.0  17.099934   8.193510 -30.902872
# Restaurant_longitude         11399.0  70.399259  22.773144 -88.400467
# Delivery_location_latitude   11399.0  17.569497   7.287440   0.010000
# Delivery_location_longitude  11399.0  71.102187  20.693782   0.010000
# Vehicle_condition            11399.0   1.031406   0.839599   0.000000
#
#                                    25%        50%        75%        max
# Restaurant_latitude          12.933284  18.551440  22.732225  30.914057
# Restaurant_longitude         73.170937  75.897429  78.045732  88.433452
# Delivery_location_latitude   12.992532  18.643481  22.791226  31.054057
# Delivery_location_longitude  73.771081  75.996959  78.109004  88.563452
# Vehicle_condition             0.000000   1.000000   2.000000   3.000000

# %%
#describe(include=’all’) provides a statistics summary of all data, include object, category etc
print(data.describe(include='all').T)
# Out:
#                                count unique               top   freq  \
# ID                             11399  11399           0xb7be       1
# Delivery_person_ID             11399   1297    MUMRES11DEL02      24
# Delivery_person_Age            11399     23                30    579
# Delivery_person_Ratings        11399     29               4.9   1863
# Restaurant_latitude          11399.0    NaN               NaN    NaN
# Restaurant_longitude         11399.0    NaN               NaN    NaN
# Delivery_location_latitude   11399.0    NaN               NaN    NaN
# Delivery_location_longitude  11399.0    NaN               NaN    NaN
# Order_Date                     11399     44        01-04-2022    307
# Time_Orderd                    11399    177              NaN     444
# Time_Order_picked              11399    193          19:25:00    133
# Weatherconditions              11399      7  conditions Sunny   1975
# Road_traffic_density           11399      5              Low    3881
# ...

# %%
#separate Numerical and categorical variables for easy analysis
cat_cols=data.select_dtypes(include=['object']).columns
num_cols = data.select_dtypes(include=np.number).columns.tolist()
print("Categorical Variables:")
print(cat_cols)
print("Numerical Variables:")
print(num_cols)
# Out:
# Categorical Variables:
# Index(['ID', 'Delivery_person_ID', 'Delivery_person_Age',
#        'Delivery_person_Ratings', 'Order_Date', 'Time_Orderd',
#        'Time_Order_picked', 'Weatherconditions', 'Road_traffic_density',
#        'Type_of_order', 'Type_of_vehicle', 'multiple_deliveries', 'Festival',
#        'City'],
#       dtype='object')
# Numerical Variables:
# ['Restaurant_latitude', 'Restaurant_longitude', 'Delivery_location_latitude', 'Delivery_location_longitude', 'Vehicle_condition']

# %%
#boxplot
for col in num_cols:
    print(col)
    print('Skew :', round(data[col].skew(), 2))
    plt.figure(figsize = (10, 3))
    plt.subplot(1, 2, 1)
    data[col].hist(grid=False)
    plt.ylabel('count')
    plt.subplot(1, 2, 2)
    sns.boxplot(x=data[col])
    plt.show()
# Out:
# Restaurant_latitude
# Skew : -1.4
# Restaurant_longitude
# Skew : -3.34
# Delivery_location_latitude
# Skew : -0.7
# Delivery_location_longitude
# Skew : -3.04
# Vehicle_condition
# Skew : 0.05

# %%
# Set up the plot grid
fig, axes = plt.subplots(3, 2, figsize=(15, 15))
fig.suptitle('Bar Plot for All Categorical Variables in the Dataset')

# Define categorical columns to visualize
categorical_columns = ['Weatherconditions', 'Road_traffic_density', 'Type_of_order', 
                       'Type_of_vehicle', 'Festival', 'City']

# Generate count plots
for ax, col in zip(axes.flatten(), categorical_columns):
    sns.countplot(ax=ax, x=col, data=data, color='skyblue', 
                  order=data[col].value_counts().index)
    ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

plt.tight_layout(rect=[0, 0.03, 1, 0.97])
plt.show()

# %%
# Histogram
plt.figure(figsize=(6, 3))
sns.histplot(data['Vehicle_condition'], bins=10, kde=True, color='blue')
plt.title("Histogram of Vehicle Condition")
plt.xlabel("Vehicle Condition")
plt.ylabel("Frequency")
plt.show()

# %%
# Scatter Plot
plt.figure(figsize=(6, 3))
sns.scatterplot(x=data['Restaurant_latitude'], y=data['Delivery_location_latitude'], hue=data['Road_traffic_density'])
plt.title("Scatter Plot of Restaurant vs Delivery Location Latitude")
plt.xlabel("Restaurant Latitude")
plt.ylabel("Delivery Location Latitude")
plt.show()

# %%
# Pie Chart
plt.figure(figsize=(6, 6))
data['Type_of_order'].value_counts().plot.pie(autopct="%1.1f%%", colors=["blue", "orange", "green", "red"])
plt.title("Pie Chart of Type of Order")
plt.ylabel("")
plt.show()
